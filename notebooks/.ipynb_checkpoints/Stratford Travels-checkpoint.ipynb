# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
years = [str(y) for y in range(2007,2018)]
growth_boroughs = ['Greenwich', 'Hackney', 'Newham', 'Tower Hamlets', 'Barking and Dagenham', 'Waltham Forest']

boroughs = ['City of London', 'Barking and Dagenham', 'Barnet', 'Bexley',
       'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
       'Greenwich', 'Hackney', 'Hammersmith and Fulham', 'Haringey',
       'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
       'Kensington and Chelsea', 'Kingston-upon-Thames', 'Lambeth',
       'Lewisham', 'Merton', 'Newham', 'Redbridge',
       'Richmond-upon-Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
       'Waltham Forest', 'Wandsworth', 'Westminster']

west_boroughs = list(set(boroughs).difference(set(growth_boroughs)))

# %%
def plot_stations(data, col, highlight_stations, see_stations):
    plt.xticks(np.arange(0,18),years, rotation=90)
    for station in see_stations:
        station_by_year = data[data['station'] == station]
        if station_by_year.empty:
            continue
        station_by_year = station_by_year[col].values
        if station in highlight_stations: 
            plt.plot(station_by_year, label=station, linewidth=2)
        else: 
            plt.plot(station_by_year, color='gray', linewidth=1, linestyle=':')
    plt.legend()
    plt.show()

# %%
def plot_all_stations(data, col):
    plt.xticks(np.arange(0,18),years, rotation=90)
    for station in stations:
        station_by_year = data[data['station'] == station]
        if station_by_year.empty:
            continue
        station_by_year = station_by_year[col].values
        if station in growth_stations: 
            plt.plot(station_by_year, label=station, linewidth=2)
        else: 
            plt.plot(station_by_year, color='gray', linewidth=1, linestyle=':')
    plt.legend()
    plt.show()

# %%
underground = pd.read_csv('../data/london_underground_activity.csv')

underground.isna().sum()
# Out:
# year                     0
# nlc                      0
# station                  0
# area                     7
# weekday_entry            0
# weekday_exit             0
# saturday_entry           0
# saturday_exit            0
# sunday_entry             0
# sunday_exit              0
# annual_entry_and_exit    0
# dtype: int64

# %%
# we don't use Area from this dataset
underground.dropna(axis=1, inplace=True)
underground.head()
# Out:
#    year  nlc       station  weekday_entry  weekday_exit  saturday_entry  \
# 0  2007  500    Acton Town           9205        8899.0            6722
# 1  2007  502       Aldgate           9887       10397.0            2191
# 2  2007  503  Aldgate East          12820       12271.0            7040
# 3  2007  505      Alperton           4611        4719.0            3354
# 4  2007  506      Amersham           4182        3938.0            1709
#
#    saturday_exit  sunday_entry  sunday_exit  annual_entry_and_exit
# 0           6320          4427         4304                   5.77
# 1           2587          1484         1772                   5.57
# 2           6220          5505         5000                   7.66
# 3           3450          2433         2503                   3.01
# 4           1585          1004          957                   2.34

# %% [markdown]
# # Stations in the growth boroughs

# %%
info = pd.read_csv('../data/london_underground_station_info.csv')
info_growth_boroughs = info[info['local_authority'].isin(growth_boroughs)]
info_growth_boroughs.head()
# Out:
#             station                   line       local_authority zone  \
# 2      Aldgate East  Hammersmith & City[d]         Tower Hamlets    1
# 13          Barking            District[j]  Barking and Dagenham    4
# 17        Becontree               District  Barking and Dagenham    5
# 20    Bethnal Green                Central         Tower Hamlets    2
# 22  Blackhorse Road               Victoria        Waltham Forest    3
#
#         opened
# 2   1884-10-06
# 13  1902-06-02
# 17  1932-07-18
# 20  1946-12-04
# 22  1968-09-01

# %%
stations = list(info['station'])
growth_stations = list(info_growth_boroughs['station'])
len(growth_stations)
# Out:
# 26

# %% [markdown]
# ## Stratford vs all other east boroughs

# %%
highlight_stations = ['Stratford', 'Canary Wharf']
plot_stations(underground, "annual_entry_and_exit", highlight_stations, growth_stations)

# %%
highlight_stations = ['Stratford', 'Canary Wharf']
plot_stations(underground, "weekday_entry", highlight_stations, growth_stations)

# %%
highlight_stations = ["Stratford"]
plot_stations(underground, "saturday_entry", highlight_stations, growth_stations)

# %%
highlight_stations = ["Stratford"]
plot_stations(underground, "sunday_entry", highlight_stations, growth_stations)

# %% [markdown]
# # Stations in the east boroughs vs all

# %% [markdown]
# ## Absolute value

# %%
year_2007 = underground[underground['year'] == 2007]

big_stations_data = year_2007[year_2007['saturday_entry'] >= 80000]
big_stations = list(big_stations_data['station'].values)
big_stations
# Out:
# ["King's Cross St. Pancras", 'Oxford Circus', 'Victoria']

# %%
highlight_stations = big_stations + ['Stratford']
plot_stations(underground, "saturday_entry", highlight_stations, stations)

# %%
plot_all_stations(underground, "saturday_entry")

# %% [markdown]
# # Stratford

# %%
stratford_underground = underground[ underground['station'] == 'Stratford']
stratford_underground
# Out:
#       year  nlc    station    area  weekday_entry  weekday_exit  \
# 222   2007  719  Stratford  Newham          40084       38540.0
# 491   2008  719  Stratford  Newham          39831       43902.0
# 759   2009  719  Stratford  Newham          36963       43449.0
# 1027  2010  719  Stratford  Newham          46643       45812.0
# 1295  2011  719  Stratford  Newham          70198       66657.0
# 1563  2012  719  Stratford  Newham          74238       71501.0
# 1831  2013  719  Stratford  Newham          80455       76757.0
# 2099  2014  719  Stratford  Newham          86183       83030.0
# 2367  2015  719  Stratford  Newham          91067       82048.0
# 2621  2016  719  Stratford  Newham          98387       92017.0
# 2903  2017  719  Stratford  Newham          93742       86285.0
#
#       saturday_entry  saturday_exit  sunday_entry  sunday_exit  \
# 222            30755          31154         21334        21310
# 491            31524          30151         24060        24067
# 759            34983          35383         24733        25885
# 1027           37198          34589         23475        22210
# 1295           81848          75104         51574        46485
# 1563           79991          75360         52801        49109
# 1831           83432          78651         55245        51541
# 2099           92110          88485         61847        58602
# 2367          100280          92440         67894        61311
# 2621          100920          97318         74689        70509
# 2903           93482          87548         61629        57524
#
#       annual_entry_and_exit
# 222                25.63000
# 491                27.23000
# 759                26.99000
# 1027               29.82000
# 1295               48.57000
# 1563               50.96000
# 1831               54.50000
# 2099               59.31000
# 2367               61.44263
# 2621               67.05000
# 2903               61.99000

# %%
weekday = stratford_underground['weekday_entry']
plt.plot(weekday)

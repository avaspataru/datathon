# %% [markdown]
# # Setup

# %% [markdown]
# ## Import modules

# %%
import sys

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import global variables and plotting functions

# %%
sys.path.insert(0, '..')

# global vars
from util_scripts.plotting_fcts_and_vars import years, growth_boroughs, boroughs, west_boroughs, columns, types

# plotting per borrough
from util_scripts.plotting_fcts_and_vars import plot_boroughs, plot_all_boroughs

# plotting stations data
from util_scripts.plotting_fcts_and_vars import plot_stations, plot_stations_changes

# plotting global vars
from util_scripts.plotting_fcts_and_vars import FIGSIZE, YEAR_XLABEL, PLOTS_DIR, GROWTH_MULTIPLIER, POINT_CHANGE

sys.path.insert(0, './notebooks')

# %% [markdown]
# # Number of restaurants by borough

# %%
# load
restaurants_units = pd.read_excel("../data/restaurants-cafes-borough.xls", sheet_name="Restaurants units", skiprows=4, names=columns)

# remove missing values
restaurants_units.dropna(axis=0, inplace=True)
restaurants_units.head()
# Out:
#    Area code             Area name    2001    2002    2003    2004    2005  \
# 0  E12000007                London  5455.0  5525.0  5540.0  5575.0  5915.0
# 1  E09000001        City of London   180.0   190.0   190.0   175.0   180.0
# 2  E09000002  Barking and Dagenham    30.0    30.0    30.0    35.0    35.0
# 3  E09000003                Barnet   205.0   195.0   200.0   200.0   200.0
# 4  E09000004                Bexley    85.0    80.0    75.0    80.0    85.0
#
#      2006    2007    2008    2009    2010    2011    2012    2013    2014  \
# 0  5940.0  6175.0  5985.0  5910.0  6175.0  6210.0  6655.0  6715.0  7035.0
# 1   170.0   205.0   185.0   180.0   195.0   190.0   205.0   230.0   255.0
# 2    35.0    35.0    35.0    30.0    30.0    30.0    40.0    40.0    35.0
# 3   200.0   205.0   195.0   210.0   215.0   205.0   235.0   250.0   240.0
# 4    95.0    95.0    95.0    90.0    95.0    95.0   105.0   105.0   105.0
#
#      2015    2016    2017
# 0  7515.0  7745.0  7990.0
# 1   270.0   270.0   295.0
# 2    45.0    40.0    35.0
# 3   255.0   245.0   270.0
# 4   100.0   110.0   110.0

# %% [markdown]
# ## Values for growth boroughs

# %%
restaurants_units_boroughs = restaurants_units[restaurants_units['Area name'].isin(growth_boroughs)]
restaurants_units_boroughs
# Out:
#     Area code             Area name   2001   2002   2003   2004   2005   2006  \
# 2   E09000002  Barking and Dagenham   30.0   30.0   30.0   35.0   35.0   35.0
# 11  E09000011             Greenwich   70.0   75.0   65.0   75.0   70.0   75.0
# 12  E09000012               Hackney   95.0  100.0  100.0  110.0  110.0  120.0
# 25  E09000025                Newham   45.0   55.0   50.0   60.0   75.0   85.0
# 30  E09000030         Tower Hamlets  135.0  160.0  165.0  175.0  175.0  180.0
# 31  E09000031        Waltham Forest   75.0   70.0   65.0   65.0   85.0   80.0
#
#      2007   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 2    35.0   35.0   30.0   30.0   30.0   40.0   40.0   35.0   45.0   40.0
# 11   90.0   95.0   90.0  100.0  100.0  120.0  125.0  120.0  125.0  140.0
# 12  120.0  130.0  120.0  125.0  140.0  160.0  165.0  180.0  230.0  245.0
# 25   85.0   80.0   75.0   80.0   75.0   95.0  110.0  110.0  120.0  120.0
# 30  200.0  195.0  210.0  215.0  215.0  245.0  260.0  285.0  300.0  320.0
# 31   85.0   80.0   65.0   75.0   80.0   95.0   95.0   95.0  115.0  125.0
#
#      2017
# 2    35.0
# 11  145.0
# 12  285.0
# 25  125.0
# 30  320.0
# 31  135.0

# %%
plot_boroughs(restaurants_units_boroughs)

plt.show()

# %% [markdown]
# ## Percentage changes (baseline 2005)

# %%
multipliers_2005 = restaurants_units[years].div(restaurants_units["2005"], axis=0)
percentage_changes_num_2005 = multipliers_2005.sub(1)
percentage_changes_2005 = pd.concat([restaurants_units.iloc[:, :2], percentage_changes_num_2005], axis=1)
percentage_changes_2005.head()
# Out:
#    Area code             Area name      2001      2002      2003      2004  \
# 0  E12000007                London -0.077768 -0.065934 -0.063398 -0.057481
# 1  E09000001        City of London  0.000000  0.055556  0.055556 -0.027778
# 2  E09000002  Barking and Dagenham -0.142857 -0.142857 -0.142857  0.000000
# 3  E09000003                Barnet  0.025000 -0.025000  0.000000  0.000000
# 4  E09000004                Bexley  0.000000 -0.058824 -0.117647 -0.058824
#
#    2005      2006      2007      2008      2009      2010      2011      2012  \
# 0   0.0  0.004227  0.043956  0.011834 -0.000845  0.043956  0.049873  0.125106
# 1   0.0 -0.055556  0.138889  0.027778  0.000000  0.083333  0.055556  0.138889
# 2   0.0  0.000000  0.000000  0.000000 -0.142857 -0.142857 -0.142857  0.142857
# 3   0.0  0.000000  0.025000 -0.025000  0.050000  0.075000  0.025000  0.175000
# 4   0.0  0.117647  0.117647  0.117647  0.058824  0.117647  0.117647  0.235294
#
#        2013      2014      2015      2016      2017
# 0  0.135249  0.189349  0.270499  0.309383  0.350803
# 1  0.277778  0.416667  0.500000  0.500000  0.638889
# 2  0.142857  0.000000  0.285714  0.142857  0.000000
# 3  0.250000  0.200000  0.275000  0.225000  0.350000
# 4  0.235294  0.235294  0.176471  0.294118  0.294118

# %%
plot_all_boroughs(percentage_changes_2005)

plt.show()

# %% [markdown]
# ## Percentage changes (baseline 2011)

# %%
multipliers_2011 = restaurants_units[years].div(restaurants_units["2011"], axis=0)
percentage_changes_num_2011 = multipliers_2011.sub(1)
percentage_changes_2011 = pd.concat([restaurants_units.iloc[:, :2], percentage_changes_num_2011], axis=1)
percentage_changes_2011.head()
# Out:
#    Area code             Area name      2001      2002      2003      2004  \
# 0  E12000007                London -0.121578 -0.110306 -0.107890 -0.102254
# 1  E09000001        City of London -0.052632  0.000000  0.000000 -0.078947
# 2  E09000002  Barking and Dagenham  0.000000  0.000000  0.000000  0.166667
# 3  E09000003                Barnet  0.000000 -0.048780 -0.024390 -0.024390
# 4  E09000004                Bexley -0.105263 -0.157895 -0.210526 -0.157895
#
#        2005      2006      2007      2008      2009      2010  2011      2012  \
# 0 -0.047504 -0.043478 -0.005636 -0.036232 -0.048309 -0.005636   0.0  0.071659
# 1 -0.052632 -0.105263  0.078947 -0.026316 -0.052632  0.026316   0.0  0.078947
# 2  0.166667  0.166667  0.166667  0.166667  0.000000  0.000000   0.0  0.333333
# 3 -0.024390 -0.024390  0.000000 -0.048780  0.024390  0.048780   0.0  0.146341
# 4 -0.105263  0.000000  0.000000  0.000000 -0.052632  0.000000   0.0  0.105263
#
#        2013      2014      2015      2016      2017
# 0  0.081320  0.132850  0.210145  0.247182  0.286634
# 1  0.210526  0.342105  0.421053  0.421053  0.552632
# 2  0.333333  0.166667  0.500000  0.333333  0.166667
# 3  0.219512  0.170732  0.243902  0.195122  0.317073
# 4  0.105263  0.105263  0.052632  0.157895  0.157895

# %%
plot_all_boroughs(percentage_changes_2011)

plt.show()

# %% [markdown]
# # Number of restaurant employees by borough

# %%
# load
restaurants_employees = pd.read_excel("../data/restaurants-cafes-borough.xls", sheet_name="Restaurants employment", skiprows=4, names=columns)

# remove missing values
restaurants_employees.dropna(axis=0, inplace=True)
restaurants_employees.head()
# Out:
#    Area code             Area name     2001     2002     2003     2004  \
# 0  E12000007                London  63800.0  69800.0  70900.0  69100.0
# 1  E09000001        City of London   2400.0   2900.0   3100.0   2900.0
# 2  E09000002  Barking and Dagenham    300.0    300.0    300.0    300.0
# 3  E09000003                Barnet   1600.0   1600.0   1600.0   1500.0
# 4  E09000004                Bexley    800.0    800.0    800.0    800.0
#
#       2005     2006     2007     2008     2009     2010     2011     2012  \
# 0  71400.0  71400.0  71500.0  68300.0  71100.0  79000.0  83600.0  90700.0
# 1   3000.0   2900.0   3100.0   2800.0   2900.0   3200.0   3200.0   3700.0
# 2    300.0    300.0    300.0    300.0    200.0    300.0    300.0    300.0
# 3   1500.0   1500.0   1700.0   1400.0   2100.0   2300.0   1700.0   1800.0
# 4    700.0    800.0    800.0    600.0    600.0    700.0    800.0    800.0
#
#       2013      2014      2015      2016      2017
# 0  95300.0  104000.0  112800.0  118600.0  124500.0
# 1   4200.0    5200.0    5900.0    6700.0    6800.0
# 2    300.0     300.0     300.0     400.0     300.0
# 3   2100.0    2200.0    2400.0    2400.0    2900.0
# 4    800.0     800.0     800.0    1000.0    1000.0

# %% [markdown]
# ## Values for growth boroughs

# %%
restaurants_employees_boroughs = restaurants_employees[restaurants_employees['Area name'].isin(growth_boroughs)]
restaurants_employees_boroughs
# Out:
#     Area code             Area name    2001    2002    2003    2004    2005  \
# 2   E09000002  Barking and Dagenham   300.0   300.0   300.0   300.0   300.0
# 11  E09000011             Greenwich   700.0   700.0   600.0   700.0   800.0
# 12  E09000012               Hackney   600.0   600.0   800.0   900.0   900.0
# 25  E09000025                Newham   400.0   500.0   500.0   600.0   500.0
# 30  E09000030         Tower Hamlets  1300.0  1800.0  1900.0  1600.0  1700.0
# 31  E09000031        Waltham Forest   500.0   500.0   500.0   400.0   500.0
#
#       2006    2007    2008    2009    2010    2011    2012    2013    2014  \
# 2    300.0   300.0   300.0   200.0   300.0   300.0   300.0   300.0   300.0
# 11   700.0   800.0   700.0   800.0  1000.0  1200.0  1500.0  1700.0  1500.0
# 12  1000.0   900.0  1100.0  1200.0  1400.0  1800.0  2100.0  2300.0  2700.0
# 25   700.0   700.0   700.0   700.0   900.0   900.0  1100.0  1600.0  2200.0
# 30  1900.0  1900.0  1900.0  2200.0  2400.0  2800.0  3100.0  3300.0  4000.0
# 31   400.0   500.0   500.0   400.0   500.0   600.0   600.0   600.0   600.0
#
#       2015    2016    2017
# 2    300.0   400.0   300.0
# 11  1700.0  1900.0  2000.0
# 12  3700.0  4000.0  4700.0
# 25  2300.0  2400.0  2300.0
# 30  4600.0  5000.0  5200.0
# 31   700.0   900.0  1100.0

# %%
plot_boroughs(restaurants_employees_boroughs)

plt.show()

# %% [markdown]
# ## Percentage changes (baseline 2005)

# %%
multipliers_2005 = restaurants_employees[years].div(restaurants_employees["2005"], axis=0)
percentage_changes_num_2005 = multipliers_2005.sub(1)
percentage_changes_2005 = pd.concat([restaurants_employees.iloc[:, :2], percentage_changes_num_2005], axis=1)
percentage_changes_2005.head()
# Out:
#    Area code             Area name      2001      2002      2003      2004  \
# 0  E12000007                London -0.106443 -0.022409 -0.007003 -0.032213
# 1  E09000001        City of London -0.200000 -0.033333  0.033333 -0.033333
# 2  E09000002  Barking and Dagenham  0.000000  0.000000  0.000000  0.000000
# 3  E09000003                Barnet  0.066667  0.066667  0.066667  0.000000
# 4  E09000004                Bexley  0.142857  0.142857  0.142857  0.142857
#
#    2005      2006      2007      2008      2009      2010      2011      2012  \
# 0   0.0  0.000000  0.001401 -0.043417 -0.004202  0.106443  0.170868  0.270308
# 1   0.0 -0.033333  0.033333 -0.066667 -0.033333  0.066667  0.066667  0.233333
# 2   0.0  0.000000  0.000000  0.000000 -0.333333  0.000000  0.000000  0.000000
# 3   0.0  0.000000  0.133333 -0.066667  0.400000  0.533333  0.133333  0.200000
# 4   0.0  0.142857  0.142857 -0.142857 -0.142857  0.000000  0.142857  0.142857
#
#        2013      2014      2015      2016      2017
# 0  0.334734  0.456583  0.579832  0.661064  0.743697
# 1  0.400000  0.733333  0.966667  1.233333  1.266667
# 2  0.000000  0.000000  0.000000  0.333333  0.000000
# 3  0.400000  0.466667  0.600000  0.600000  0.933333
# 4  0.142857  0.142857  0.142857  0.428571  0.428571

# %%
plot_all_boroughs(percentage_changes_2005)

plt.show()

# %% [markdown]
# ## Percentage changes (baseline 2011)

# %%
multipliers_2011 = restaurants_employees[years].div(restaurants_employees["2011"], axis=0)
percentage_changes_num_2011 = multipliers_2011.sub(1)
percentage_changes_2011 = pd.concat([restaurants_employees.iloc[:, :2], percentage_changes_num_2011], axis=1)
percentage_changes_2011.head()
# Out:
#    Area code             Area name      2001      2002      2003      2004  \
# 0  E12000007                London -0.236842 -0.165072 -0.151914 -0.173445
# 1  E09000001        City of London -0.250000 -0.093750 -0.031250 -0.093750
# 2  E09000002  Barking and Dagenham  0.000000  0.000000  0.000000  0.000000
# 3  E09000003                Barnet -0.058824 -0.058824 -0.058824 -0.117647
# 4  E09000004                Bexley  0.000000  0.000000  0.000000  0.000000
#
#        2005      2006      2007      2008      2009      2010  2011      2012  \
# 0 -0.145933 -0.145933 -0.144737 -0.183014 -0.149522 -0.055024   0.0  0.084928
# 1 -0.062500 -0.093750 -0.031250 -0.125000 -0.093750  0.000000   0.0  0.156250
# 2  0.000000  0.000000  0.000000  0.000000 -0.333333  0.000000   0.0  0.000000
# 3 -0.117647 -0.117647  0.000000 -0.176471  0.235294  0.352941   0.0  0.058824
# 4 -0.125000  0.000000  0.000000 -0.250000 -0.250000 -0.125000   0.0  0.000000
#
#        2013      2014      2015      2016      2017
# 0  0.139952  0.244019  0.349282  0.418660  0.489234
# 1  0.312500  0.625000  0.843750  1.093750  1.125000
# 2  0.000000  0.000000  0.000000  0.333333  0.000000
# 3  0.235294  0.294118  0.411765  0.411765  0.705882
# 4  0.000000  0.000000  0.000000  0.250000  0.250000

# %%
plot_all_boroughs(percentage_changes_2011)

plt.show()
